# %% [markdown]
# # Descriptive statistics problems

# %% [markdown]
# ### Exercise 1
#
# We will use NumPy to obtain information to describe statistically.
#
# - Generate an array of 100 elements following a normal distribution.
# - Generate an array of 100 elements following a chi-square distribution with 3 degrees of freedom.
# - Calculate the main metrics and statistical measures that best describe the two vectors.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# Generate an array of 100 elements following a normal distribution
mu, sigma = 0, 0.1 # mean and std
normal_dist = np.random.normal(mu, sigma, 100)
count, bins, ignored = plt.hist(normal_dist, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()
normal_dist
# Out:
# array([-0.12629961,  0.16439988, -0.09990659,  0.01300797, -0.00776823,
#         0.12677237, -0.07754377, -0.01446139,  0.08155157, -0.03284939,
#        -0.10740169, -0.03247864, -0.05550597,  0.05347391, -0.00912618,
#        -0.05796636, -0.16751127, -0.14852   , -0.27306789, -0.10135941,
#         0.10689675,  0.06294456, -0.04055944, -0.09705088, -0.1140458 ,
#        -0.1642678 ,  0.04110843, -0.0651537 , -0.02792479, -0.04356956,
#         0.17241162,  0.03832287, -0.00267148, -0.0927624 , -0.06818396,
#        -0.10485228, -0.00085719, -0.01376054, -0.0230386 ,  0.09516802,
#        -0.02524776, -0.15554088, -0.02160217,  0.02072369,  0.06131293,
#         0.07062585, -0.03647388, -0.1185632 ,  0.07131603, -0.06649793,
#        -0.00099733,  0.1175313 , -0.01119168,  0.01269481,  0.00689688,
#         0.05738615, -0.17595279,  0.10597838, -0.04456291, -0.08809285,
#         0.05431128,  0.02980792,  0.14962076,  0.03831938,  0.15624948,
#        -0.14327507,  0.0074896 ,  0.00065952,  0.08372827,  0.06091246,
#        -0.02325507, -0.0648801 ,  0.07062235, -0.03817395,  0.11142584,
#        -0.16399258,  0.17007735, -0.06608949,  0.03038877,  0.06783827,
#         0.07760053, -0.11009166, -0.06999611,  0.06360651, -0.12671693,
#        -0.03908671, -0.17056317, -0.05626235, -0.13652614,  0.00570486,
#         0.0188619 ,  0.01840302, -0.06933349, -0.10463591, -0.11013517,
#         0.17288759,  0.0250521 , -0.03008805,  0.02331994,  0.15842295])

# %%
# Generate an array of 100 elements following a chi-square distribution with 3 degrees of freedom
chi_square = np.random.chisquare(3,size=100)
count, bins, _ = plt.hist(chi_square, 30, density = True)
x = np.linspace(0, 20, 100)
plt.plot(x, stats.chi2.pdf(x, df=3))
plt.xlim([0, 20])
plt.show()
chi_square
# Out:
# array([13.05070143, 10.77733951,  5.60482771,  2.48765377,  2.32819044,
#        10.45160293,  0.23873192,  6.3991637 ,  0.91806557,  2.951182  ,
#         1.24865018,  0.82492631,  2.09644117,  5.80280968,  0.52237682,
#         2.98513309,  0.54741591,  2.97061228,  1.75961413,  3.87326195,
#         1.85262878,  3.61149839,  0.67410155,  3.17249208,  0.6889273 ,
#         3.81167611,  2.21781057,  0.7167297 ,  3.62967179,  0.28460066,
#         0.89035204,  4.44273147,  0.17159682,  0.28472017,  0.74211365,
#         1.98169234,  0.72598774,  2.1944571 ,  1.33199482,  2.32707563,
#         1.013579  ,  5.69564717,  7.07963083,  2.49223956,  2.6390833 ,
#         5.07864972,  1.06314497,  2.05110626,  1.11732021,  1.4014741 ,
#         5.7067347 ,  0.36571631,  0.83207667,  1.34740567,  3.23987839,
#         1.93791635,  5.25626088,  3.03753969,  0.62639496,  0.82550383,
#         2.87943803,  8.96858988,  6.11092868,  3.81202696,  2.08958658,
#         1.24492756,  1.22669796,  3.03097097,  2.44707477,  2.40400579,
#         1.36551634,  1.50182353,  3.71010385,  0.90541792,  1.54944956,
#         1.46914122,  2.112477  ,  1.12724642,  1.91115889,  3.34433149,
#         1.13396739,  4.91898582,  0.99116689,  5.47607127,  0.45483915,
#         0.77556289,  1.71073876,  0.7814858 ,  0.30821898,  2.37570867,
#         2.17572172,  1.9962923 ,  3.77801597,  0.75106017,  1.08331222,
#         2.64250319,  5.95412705,  2.29936395,  1.26945015,  1.62639331])

# %%
# Normal Distribution
print("Normal Distribution:")
print(normal_dist.std())
print(normal_dist.mean())
# Median
# Mode
# Range
# variance
# Chi-Square Distribution
print("Chi-Square Distribution:")
print(chi_square.std())
print(chi_square.mean())
# Median
# Mode
# Range
# variance
# Out:
# Normal Distribution:
# 0.1110811081668018
# 0.012384522450219902
# Chi-Square Distribution:
# 2.1544675366331654
# 2.81640915761663

# %% [markdown]
# ### Exercise 2
#
# Write a Python program to calculate the standard deviation of the following data:
#
# ```py
# data = [4, 2, 5, 8, 6]
# ```

# %%
import math
data = [4, 2, 5, 8, 6]
data = np.array(data)
# Numpy
#print(data.std())
# Formula

print("List : " + str(data))

mean = sum(data) / len(data)

def variance():
    num = 0
    for i in data:
        num += (i - mean)**2
    return num/len(data)
    
st_dev = math.sqrt(variance())

print("Standard deviation of the given data: " + str(st_dev))
# Out:
# List : [4 2 5 8 6]
# Standard deviation of the given data: 2.0
